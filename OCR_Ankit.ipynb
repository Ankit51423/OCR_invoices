# %%
pip install pytesseract pdf2image pandas openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from pdf2image import convert_from_path
import pytesseract
import cv2

# %%
#Here i am  Convert PDF to images.
images = convert_from_path('invoice.pdf', 500, poppler_path=r"C:\\Program Files\\poppler-24.02.0\\Library\\bin")

# here is a Path to tesseract executable.
pytesseract.pytesseract.tesseract_cmd = r"C:\\Program Files\\Tesseract-OCR\\tesseract.exe"

# here is Loop through each image and extract text.
for i in range(len(images)):
    # Save the image (optional, if you want to keep the images)
    images[i].save('page' + str(i) + '.jpg', 'JPEG')
    
# here is Read the image.
    img = cv2.imread('page' + str(i) + '.jpg')
    
# here is Display image.
    cv2.imshow('Page ' + str(i), img)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    
# here is Extract text.
    text = pytesseract.image_to_string(img)
    print(f"Text from page {i}:\n{text}\n")
# Out:
# Text from page 0:
# am aZon| N Tax Invoice/Bill of Supply/Cash Memo
# wee)
#
# (Original for Recipient)
#
# Sold By : Billing Address :
# RETAILEZ PRIVATE LIMITED Ankit srivastav
# “ Building No. B01, ESR Pune Estates Pvt Ltd, Singh pg in wazirabad, Opposites post office,
# Village Ambethan, Tal: Khed, Dist: Pune, Pin Wazirabad, Sector 52, Gurugram, Harya
# 410501 GURUGRAM, HARYANA, 122022
# CHAKAN, MAHARASHTRA, 410501 IN
# IN State/UT Code: 06
# PAN No: AALCR3173P Shipping Address
# GST Registration No: 27AALCR3173P1ZN Ankit srivastav
#
# Ankit srivastav
#
# Singh pg in wazirabad, Opposites post office,
#
# Wazirabad, Sector 52, Gurugram, Harya
#
# GURUGRAM, HARYANA, 122022
#
# IN
#
# State/UT Code: 06
#
# Place of supply: HARYANA
#
# Place of delivery: HARYANA
#
# Order Number: 408-8134006-8477134 Invoice Number : PNQ3-346778
# Order Date: 04.06.2024 Invoice Details : MH-PNQ3-1931441115-2425
# Invoice Date : 04.06.2024
#
# Description at Tax |Tax |Tax Total
# ...

# %%
#Here i am  Convert PDF to images.
images = convert_from_path('flipkart.pdf', 500, poppler_path=r"C:\\Program Files\\poppler-24.02.0\\Library\\bin")

# here is a Path to tesseract executable.
pytesseract.pytesseract.tesseract_cmd = r"C:\\Program Files\\Tesseract-OCR\\tesseract.exe"

# here is Loop through each image and extract text.
for i in range(len(images)):
    # Save the image (optional, if you want to keep the images)
    images[i].save('page' + str(i) + '.jpg', 'JPEG')
    
# here is Read the image.
    img = cv2.imread('page' + str(i) + '.jpg')
    
# here is Display image.
    cv2.imshow('Page ' + str(i), img)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    
# here is Extract text.
    text = pytesseract.image_to_string(img)
    print(f"Text from page {i}:\n{text}\n")
# Out:
# Text from page 0:
# Tax Invoice
#
# Sold By: Tech-Connect Retail Private Limited ,
#
# Ship-from Address: Sunsat warehousing Pvt. Ltd., Hadbast No. 23, Village Sanpka,Tehsil Farukhnagar, District - Gurgaon, Haryana-
#
# 122503, Farukhnagar, HARYANA, India - 122503, IN-HR
# GSTIN - O6AAICA4872D1ZS
#
# Order ID: OD328932323783157100 pil To
#
# Order Date: 19-08-2023
# Invoice Date: 20-08-2023
#
# PAN: AAICA4872D
#
# CIN: U52100DL2010PTC202600
#
# Total items: 1
# Product
#
# Sports Shoes
#
# FSN:
# SHOGDAX9Z8EWEGHY
# HSN/SAC: 64039990
#
# Ahmed Kamal
#
# 68, vinayak residency, agrasen nagar,
# balakund,Kota, behind shree ji
#
# classes,Kota.
# Kota 324005 Rajasthan
# Phone: xxxXxXXXXXX
#
# Title
#
# RED TAPE Walking Shoes
#
# For Men
#
# Warranty: This is a genuine product of Red Tape.
# The product comes with a standard brand
# warranty of 45 days
#
# IGST: 18.0 %
#
# Shipping And Handling Charges
#
# Total
#
# 1
#
# Qty
#
# 1
#
# 1
#
# Ship To
#
# Ahmed Kamal
#
# ...
